# %% [markdown]
# This colab file is demo for Self Correction Human Parsing.
# </br> Please select GPU as runtime before running the code

# %%
# !pip install ninja

# %%
#Check torch version
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
#Check torchvision version
import torchvision
print(torchvision.__version__)
# Out:
# 0.20.1+cu124

# %%
#Install compatible torch and torchvision version
# !pip install torch==2.5.1 torchvision==0.20.1

# %%
# !git clone https://github.com/PeikeLi/Self-Correction-Human-Parsing
# %cd Self-Correction-Human-Parsing
# !mkdir checkpoints
# !mkdir inputs
# !mkdir outputs
# Out:
# Cloning into 'Self-Correction-Human-Parsing'...
# remote: Enumerating objects: 722, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 722 (delta 74), reused 64 (delta 64), pack-reused 548 (from 2)
# Receiving objects: 100% (722/722), 3.88 MiB | 5.83 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# /content/Self-Correction-Human-Parsing

# %% [markdown]
# Select dataset below

# %%
dataset = 'atr'         #select from ['lip', 'atr', 'pascal']

# %%
import gdown

if dataset == 'lip':
    url = 'https://drive.google.com/uc?id=1k4dllHpu0bdx38J7H28rVVLpU-kOHmnH'
elif dataset == 'atr':
    url = 'https://drive.google.com/uc?id=1ruJg4lqR_jgQPj-9K0PP-L2vJERYOxLP'
elif dataset == 'pascal':
    url = 'https://drive.google.com/uc?id=1E5YwNKW2VOEayK9mWCS3Kpsxf-3z04ZE'

output = 'checkpoints/final.pth'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ruJg4lqR_jgQPj-9K0PP-L2vJERYOxLP
# From (redirected): https://drive.google.com/uc?id=1ruJg4lqR_jgQPj-9K0PP-L2vJERYOxLP&confirm=t&uuid=eb7f2a08-60b9-4b1e-af4d-8254de4386d6
# To: /content/Self-Correction-Human-Parsing/checkpoints/final.pth
# 100%|██████████| 267M/267M [00:03<00:00, 87.0MB/s]
# 'checkpoints/final.pth'

# %%
#Please select images which you want to upload
# %cd inputs
from google.colab import files
uploaded = files.upload()
# %cd ..
# Out:
# /content/Self-Correction-Human-Parsing/inputs
#      <input type="file" id="files-f4d5164a-e2ca-459f-b632-d84b8f7d5d0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4d5164a-e2ca-459f-b632-d84b8f7d5d0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
#Unzip Uploaded Inputs
# !unzip vogue-4.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: vogue-4/image_62045.jpg
#   inflating: vogue-4/image_62723.jpg
#   inflating: vogue-4/image_54291.jpg
#   inflating: vogue-4/image_52838.jpg
#   inflating: vogue-4/image_64352.jpg
#   inflating: vogue-4/image_68568.jpg
#   inflating: vogue-4/image_60134.jpg
#   inflating: vogue-4/image_57798.jpg
#   inflating: vogue-4/image_67883.jpg
#   inflating: vogue-4/image_56486.jpg
#   inflating: vogue-4/image_66545.jpg
#   inflating: vogue-4/image_69676.jpg
#   inflating: vogue-4/image_57940.jpg
#   inflating: vogue-4/image_67868.jpg
#   inflating: vogue-4/image_68583.jpg
#   inflating: vogue-4/image_59986.jpg
#   inflating: vogue-4/image_69845.jpg
#   inflating: vogue-4/image_57773.jpg
#   inflating: vogue-4/image_58440.jpg
#   inflating: vogue-4/image_53515.jpg
#   inflating: vogue-4/image_62910.jpg
#   inflating: vogue-4/image_55164.jpg
#   inflating: vogue-4/image_55602.jpg
#   inflating: vogue-4/image_53273.jpg
# ...

# %%
# !python3 simple_extractor.py --dataset 'atr' --model-restore 'checkpoints/final.pth' --input-dir 'vogue-4' --output-dir 'vogue-4-schp'
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Evaluating total class number 18 with ['Background', 'Hat', 'Hair', 'Sunglasses', 'Upper-clothes', 'Skirt', 'Pants', 'Dress', 'Belt', 'Left-shoe', 'Right-shoe', 'Face', 'Left-leg', 'Right-leg', 'Left-arm', 'Right-arm', 'Bag', 'Scarf']
# ...

# %%
#Zip Output Folder
# !zip -r vogue-4-schp.zip vogue-4-schp
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: vogue-4-schp/image_66756.png (deflated 2%)
#   adding: vogue-4-schp/image_65596.png (deflated 9%)
#   adding: vogue-4-schp/image_53737.png (deflated 11%)
#   adding: vogue-4-schp/image_54404.png (deflated 4%)
#   adding: vogue-4-schp/image_63794.png (stored 0%)
#   adding: vogue-4-schp/image_57469.png (deflated 12%)
#   adding: vogue-4-schp/image_57407.png (deflated 16%)
#   adding: vogue-4-schp/image_61058.png (deflated 8%)
#   adding: vogue-4-schp/image_57532.png (deflated 12%)
#   adding: vogue-4-schp/image_65190.png (deflated 12%)
#   adding: vogue-4-schp/image_59697.png (deflated 6%)
#   adding: vogue-4-schp/image_53025.png (deflated 19%)
#   adding: vogue-4-schp/image_69977.png (deflated 15%)
#   adding: vogue-4-schp/image_69241.png (deflated 5%)
#   adding: vogue-4-schp/image_66032.png (deflated 5%)
#   adding: vogue-4-schp/image_57258.png (deflated 4%)
#   adding: vogue-4-schp/image_59202.png (stored 0%)
# ...

# %% [markdown]
# # Download the generated images from *outputs* folder
